# %%
from forse.networks.resunet  import ResUNet
import pylab as pl 
from forse.mmmtools import *
# Out:
# Using TensorFlow backend.

# %%
resunet = ResUNet(epochs=1,  output_directory='/Users/peppe/work/super-reso')
# Out:
# 64

# %%
#resunet.load_model()

# %%
resunet.train(patches_file='/Users/peppe/work/super-reso/training_set_1000patches_T_1deg_5deg_Npix64.npy' )
# Out:
# WARNING:tensorflow:From /Users/peppe/miniconda/envs/pyML/lib/python3.7/site-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/peppe/miniconda/envs/pyML/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
resunet.model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# dropout_enc_1 (Dropout)         (None, 64, 64, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv_enc_1 (Conv2D)             (None, 64, 64, 64)   1664        dropout_enc_1[0][0]
# __________________________________________________________________________________________________
# seLU_enc_1 (Activation)         (None, 64, 64, 64)   0           conv_enc_1[0][0]
# __________________________________________________________________________________________________
# BN_enc_1 (BatchNormalization)   (None, 64, 64, 64)   256         seLU_enc_1[0][0]
# ...
