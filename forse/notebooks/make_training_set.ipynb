# %%
import matplotlib.pyplot as plt
from forse.tools.nn_tools import *
from forse.tools.img_tools import *
from forse.tools.mix_tools import *
import healpy as hp

# %%
repo_dir = '/global/u1/k/krach/maps_repo/'
hfi02 = hp.read_map(repo_dir+'HFI_SkyMap_353-psb-field-IQU_2048_R3.00_full_smt0.2deg.fits', (0,1,2))
hfi1 = hp.read_map(repo_dir+'HFI_SkyMap_353-psb-field-IQU_2048_R3.00_full_smt1.0deg.fits', (0,1,2))
hfi5 = hp.read_map(repo_dir+'HFI_SkyMap_353-psb-field-IQU_2048_R3.00_full_smt5.0deg.fits', (0,1,2))
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
patchesLS = make_patches_from_healpix(1000, hfi1[0], hfi5[0], 64, 20, lat_lim=10., seed=100)

# %%
patchesSS = make_patches_from_healpix(1000, hfi02[0], hfi1[0], 64, 4, lat_lim=30., seed=100)

# %%
patchesSS_large = make_patches_from_healpix(1000, hfi02[0], hfi1[0], 320, 20, lat_lim=10., seed=100)

# %%
N=403
plt.figure(figsize=(15, 8))
plt.subplot(141)
plt.imshow(patchesSS[0][N])
plt.subplot(142)
plt.imshow(patchesSS[1][N])

# %%
N = 530
plt.figure(figsize=(15, 8))
plt.subplot(141)
plt.imshow(patchesLS[0][N]/patchesLS[1][N])
plt.subplot(142)
plt.imshow(patchesLS[1][N])
plt.subplot(143)
plt.imshow(patchesSS[0][N]/patchesSS[1][N])
plt.subplot(144)
plt.imshow(patchesSS[1][N])

# %%
patch_path = '/global/homes/k/krach/scratch/NNforFG/training_set/'
np.save(patch_path+'training_set_1000patches_4x4deg_T_HR12amin_LR1deg_Npix64_lat30.npy', patchesSS)

# %%
patches = make_patches_from_healpix(1000, hfi1, hfi5, 320, 20, lat_lim=20., seed=100)

# %%
plt.subplot(121)
plt.imshow(patches[0][0])
plt.subplot(122)
plt.imshow(patches[1][0])

# %%
np.save(patch_path+'training_set_1000patches_20x20deg_T_HR1deg_LR5deg_Npix320_set2.npy', patches)

# %%
repo_dir = '/global/homes/k/krach/scratch/NNforFG/maps/'
pysm5 = hp.read_map(repo_dir+'PySM_dust_T_nside2048_fwhm5.fits')
pysm1 = hp.read_map(repo_dir+'PySM_dust_T_nside2048_fwhm1.fits')
pysm12 = hp.read_map(repo_dir+'PySM_dust_T_nside2048_fwhm0.12.fits')
# Out:
# /global/homes/k/krach/usr/python_prefix_3.7/lib/python3.7/site-packages/healpy/fitsfunc.py:352: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   "If you are not specifying the input dtype and using the default "
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 2048
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
patches = make_patches_from_healpix(100, pysm12, pysm1, 320, 20, lat_lim=30., seed=432761)

# %%
patch_path = '/global/homes/k/krach/scratch/NNforFG/training_set/'
np.save(patch_path+'training_set_PySM_100patches_20x20deg_T_HR12amin_LR1deg_Npix320_lat30.npy', patches)

# %%
patches = make_patches_from_healpix(100, hfi02[0], hfi1[0], 320, 20, lat_lim=30., seed=432761)

# %%
patch_path = '/global/homes/k/krach/scratch/NNforFG/training_set/'
np.save(patch_path+'training_set_100patches_20x20deg_T_HR12amin_LR1deg_Npix320_lat30.npy', patches)

# %%
patches = make_train_set(1000, pysm1, pysm5, 320, 20, seed=100)

# %%
patch_path = '/global/homes/k/krach/scratch/NNforFG/training_set/'
np.save(patch_path+'training_set_PySM_1000patches_20x20def_T_HR1deg_LR5deg_Npix320_set2.npy', patches)

# %%
patches = make_train_set(1000, pysm12, pysm1, 320, 20, seed=100)

# %%
patch_path = '/global/homes/k/krach/scratch/NNforFG/training_set/'
np.save(patch_path+'training_set_PySM_1000patches_20x20def_T_HR12amin_LR1deg_Npix320_set2.npy', patches)

# %%
hp.mollview(hfi5[0])
hp.mollview(pysm12, max=5000)
